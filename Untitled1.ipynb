# %%
using Plots

# %%
#Caminante en 2-D

# %%
a=[]
b=[]
r=round(360*rand()) #angulo
s=Int(r)#convierte el angulo en un entero
l=3 #longitud del paso
x0=0
y0=0
x=x0+l*cosd(s)
y=y0+l*sind(s)
push!(a,x)
push!(b,y)
# Out:
# 1-element Array{Any,1}:
#  0.469303

# %%
    a=[0.]
    b=[0.]
    x=0
    y=0
    l=2 #longitud del paso
    @gif for i in range(1,100)
        sleep(1)
        r=round(360*rand()) #angulo
        s=Int(r)#convierte el angulo en un entero
        x=x+l*cosd(s)
        y=y+l*sind(s)
        push!(a,x)
        push!(b,y)
        plot(a,b,m='o',xlims=[-13,13],ylims=[-13,13])
    end
# Out:
# INFO: Package ImageMagick is already installed
# INFO: METADATA is out-of-date — you may not have the latest version of ImageMagick
# INFO: Use `Pkg.update()` to get the latest versions of your packages
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.
# ...

# %%
plot(a,b,m='o',xlims=[-10,10])

# %%
function caminante(n)    
    a=[0.]
    b=[0.]
    c=[]
    x=0
    y=0
    l=2 #longitud del paso
    @gif for i in range(1,n)
        r=round(360*rand()) #angulo
        s=Int(r)#convierte el angulo en un entero
        x=x+l*cosd(s)
        y=y+l*sind(s)
        push!(a,x)
        push!(b,y)
    end
end
# Out:
# caminante (generic function with 1 method)

# %%
plot(a,b,m='o')
# Out:
# WARNING: Skipped marker arg o.
# WARNING: Skipped marker arg o.

# %%
#primero vamos a animar a un solo caminante

# %%
Pkg.add("ImageMagick")
# Out:
# INFO: Package ImageMagick is already installed
# INFO: METADATA is out-of-date — you may not have the latest version of ImageMagick
# INFO: Use `Pkg.update()` to get the latest versions of your packages
